# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sviro.dataset import SVIRODetection
import matplotlib.pyplot as plt
import numpy as np

from sviro.utils.image import draw_bounding_boxes

# %%
dataset = SVIRODetection(dataroot='../data', car=['x5'], split='train', mapping={
                     'infant_seat': 1})

# %%
len(dataset)
# Out:
# 789

# %%
img, target = dataset[2]    
image = draw_bounding_boxes(img, target['boxes'])
plt.imshow(image)
plt.show()
# Out:
# [562. 317. 955. 639.]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
